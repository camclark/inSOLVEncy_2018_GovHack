# %%
from __future__ import division
from __future__ import print_function
from __future__ import absolute_import

import matplotlib
matplotlib.use('TkAgg') 
import numpy as np 
import pandas as pd
import os

import seaborn as sns
from matplotlib import pyplot as plt
sns.set_style("whitegrid")
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

USER_DIR = os.path.expanduser('~')
TMP_DIR = os.path.join(USER_DIR, 'tmp','gcoast')

COLUMN_JSON = os.path.join(TMP_DIR, 'columns.json')
COLUMNS_SORTED_PATH = os.path.join(TMP_DIR, 'columns_sorted.csv')
# WEIGHTS_JSON = os.path.join(TMP_DIR, 'weights.npy')

# data = sns.load_dataset(COLUMNS_SORTED_PATH)
df = pd.read_csv(COLUMNS_SORTED_PATH)
df = df[:25]

sns.set_color_codes("pastel")
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(11.7, 8.27)

sns.barplot(x=df['w'].values, y=list(df['columns']),
            label="Total", color="b")
